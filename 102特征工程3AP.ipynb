# %%
import pandas as pd

# %%
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# %%
data = pd.read_csv('train3AP.csv')
data = data.dropna(subset=['throughput'])
data = data[data['nss'] != 0]

# %%
data2 = pd.DataFrame()
data2['loc_id'] = data['loc_id']
data2['protocol'] = data['protocol']
data2['bss_id'] = data['bss_id']
data2['sta_mac'] = data['sta_mac']
data2['pd'] = data['pd']
data2['ed'] = data['ed']
data2['nav'] = data['nav']
data2['eirp'] = data['eirp']

def try_convert_to_list(x):
    try:
        if isinstance(x, str):
            return eval(x)
        return x
    except:
        return x
columns = ['ap_from_ap_0_sum_ant_rssi', 'ap_from_ap_0_max_ant_rssi', 'ap_from_ap_0_mean_ant_rssi',
           'ap_from_ap_1_sum_ant_rssi', 'ap_from_ap_1_max_ant_rssi', 'ap_from_ap_1_mean_ant_rssi',
          'ap_from_ap_2_sum_ant_rssi', 'ap_from_ap_2_max_ant_rssi', 'ap_from_ap_2_mean_ant_rssi']
for column in columns:
    data[column] = data[column].apply(try_convert_to_list)

calculate_length = lambda x: len(x) if isinstance(x, list) else 0
calculate_同步 = lambda x: len([i for i in x if i > -62]) if isinstance(x, list) else 0
calculate_异步 = lambda x: len([i for i in x if -82 <= i <= -62]) if isinstance(x, list) else 0
calculate_NAV = lambda x: len([i for i in x if -86 <= i < -82]) if isinstance(x, list) else 0
calculate_sum = lambda x: sum(x) if isinstance(x, list) else 0
#ap_from_ap_0
data2['个数ap_from_ap_0_sum_ant_rssi'] = data['ap_from_ap_0_sum_ant_rssi'].apply(calculate_length)
data2['同步传输个数ap_from_ap_0_sum_ant_rssi'] = data['ap_from_ap_0_sum_ant_rssi'].apply(calculate_同步)
data2['同步占比ap_from_ap_0_sum_ant_rssi'] = data2['同步传输个数ap_from_ap_0_sum_ant_rssi']/data2['个数ap_from_ap_0_sum_ant_rssi']
data2['异步传输个数ap_from_ap_0_sum_ant_rssi'] = data['ap_from_ap_0_sum_ant_rssi'].apply(calculate_异步)
data2['异步占比ap_from_ap_0_sum_ant_rssi'] = data2['异步传输个数ap_from_ap_0_sum_ant_rssi']/data2['个数ap_from_ap_0_sum_ant_rssi']
data.loc[data['nav'] == -86, 'NAV传输个数ap_from_ap_0_sum_ant_rssi'] = data['ap_from_ap_0_sum_ant_rssi'].apply(calculate_NAV)
data2['NAV传输个数ap_from_ap_0_sum_ant_rssi'] = data['NAV传输个数ap_from_ap_0_sum_ant_rssi'].fillna(0)
data2['NAV占比ap_from_ap_0_sum_ant_rssi'] = data2['NAV传输个数ap_from_ap_0_sum_ant_rssi']/data2['个数ap_from_ap_0_sum_ant_rssi']
data2['其他传输个数ap_from_ap_0_sum_ant_rssi'] = data2['个数ap_from_ap_0_sum_ant_rssi']-data2['同步传输个数ap_from_ap_0_sum_ant_rssi']-data2['异步传输个数ap_from_ap_0_sum_ant_rssi']-data2['NAV传输个数ap_from_ap_0_sum_ant_rssi']
data2['其他占比ap_from_ap_0_sum_ant_rssi'] = data2['其他传输个数ap_from_ap_0_sum_ant_rssi']/data2['个数ap_from_ap_0_sum_ant_rssi']
data2['sum_ap_from_ap_0_sum_ant_rssi'] = data['ap_from_ap_0_sum_ant_rssi'].apply(calculate_sum)
data2['mean_ap_from_ap_0_sum_ant_rssi'] = data2['sum_ap_from_ap_0_sum_ant_rssi']/data2['个数ap_from_ap_0_sum_ant_rssi']
data2['空闲ap_from_ap_0_sum_ant_rssi'] = data2['其他占比ap_from_ap_0_sum_ant_rssi']
data2['繁忙ap_from_ap_0_sum_ant_rssi'] = data2['个数ap_from_ap_0_sum_ant_rssi']-data2['其他占比ap_from_ap_0_sum_ant_rssi']

data2['个数ap_from_ap_0_max_ant_rssi'] = data['ap_from_ap_0_max_ant_rssi'].apply(calculate_length)
data2['同步传输个数ap_from_ap_0_max_ant_rssi'] = data['ap_from_ap_0_max_ant_rssi'].apply(calculate_同步)
data2['同步占比ap_from_ap_0_max_ant_rssi'] = data2['同步传输个数ap_from_ap_0_max_ant_rssi']/data2['个数ap_from_ap_0_max_ant_rssi']
data2['异步传输个数ap_from_ap_0_max_ant_rssi'] = data['ap_from_ap_0_max_ant_rssi'].apply(calculate_异步)
data2['异步占比ap_from_ap_0_max_ant_rssi'] = data2['异步传输个数ap_from_ap_0_max_ant_rssi']/data2['个数ap_from_ap_0_max_ant_rssi']
data.loc[data['nav'] == -86, 'NAV传输个数ap_from_ap_0_max_ant_rssi'] = data['ap_from_ap_0_max_ant_rssi'].apply(calculate_NAV)
data2['NAV传输个数ap_from_ap_0_max_ant_rssi'] = data['NAV传输个数ap_from_ap_0_max_ant_rssi'].fillna(0)
data2['NAV占比ap_from_ap_0_max_ant_rssi'] = data2['NAV传输个数ap_from_ap_0_max_ant_rssi']/data2['个数ap_from_ap_0_max_ant_rssi']
data2['其他传输个数ap_from_ap_0_max_ant_rssi'] = data2['个数ap_from_ap_0_max_ant_rssi']-data2['同步传输个数ap_from_ap_0_max_ant_rssi']-data2['异步传输个数ap_from_ap_0_max_ant_rssi']-data2['NAV传输个数ap_from_ap_0_max_ant_rssi']
data2['其他占比ap_from_ap_0_max_ant_rssi'] = data2['其他传输个数ap_from_ap_0_max_ant_rssi']/data2['个数ap_from_ap_0_max_ant_rssi']
data2['sum_ap_from_ap_0_max_ant_rssi'] = data['ap_from_ap_0_max_ant_rssi'].apply(calculate_sum)
data2['mean_ap_from_ap_0_max_ant_rssi'] = data2['sum_ap_from_ap_0_max_ant_rssi']/data2['个数ap_from_ap_0_max_ant_rssi']
data2['空闲ap_from_ap_0_max_ant_rssi'] = data2['其他占比ap_from_ap_0_max_ant_rssi']
data2['繁忙ap_from_ap_0_max_ant_rssi'] = data2['个数ap_from_ap_0_max_ant_rssi']-data2['其他占比ap_from_ap_0_max_ant_rssi']

data2['个数ap_from_ap_0_mean_ant_rssi'] = data['ap_from_ap_0_mean_ant_rssi'].apply(calculate_length)
data2['同步传输个数ap_from_ap_0_mean_ant_rssi'] = data['ap_from_ap_0_mean_ant_rssi'].apply(calculate_同步)
data2['同步占比ap_from_ap_0_mean_ant_rssi'] = data2['同步传输个数ap_from_ap_0_mean_ant_rssi']/data2['个数ap_from_ap_0_mean_ant_rssi']
data2['异步传输个数ap_from_ap_0_mean_ant_rssi'] = data['ap_from_ap_0_mean_ant_rssi'].apply(calculate_异步)
data2['异步占比ap_from_ap_0_mean_ant_rssi'] = data2['异步传输个数ap_from_ap_0_mean_ant_rssi']/data2['个数ap_from_ap_0_mean_ant_rssi']
data.loc[data['nav'] == -86, 'NAV传输个数ap_from_ap_0_mean_ant_rssi'] = data['ap_from_ap_0_mean_ant_rssi'].apply(calculate_NAV)
data2['NAV传输个数ap_from_ap_0_mean_ant_rssi'] = data['NAV传输个数ap_from_ap_0_mean_ant_rssi'].fillna(0)
data2['NAV占比ap_from_ap_0_mean_ant_rssi'] = data2['NAV传输个数ap_from_ap_0_mean_ant_rssi']/data2['个数ap_from_ap_0_mean_ant_rssi']
data2['其他传输个数ap_from_ap_0_mean_ant_rssi'] = data2['个数ap_from_ap_0_mean_ant_rssi']-data2['同步传输个数ap_from_ap_0_mean_ant_rssi']-data2['异步传输个数ap_from_ap_0_mean_ant_rssi']-data2['NAV传输个数ap_from_ap_0_mean_ant_rssi']
data2['其他占比ap_from_ap_0_mean_ant_rssi'] = data2['其他传输个数ap_from_ap_0_mean_ant_rssi']/data2['个数ap_from_ap_0_mean_ant_rssi']
data2['sum_ap_from_ap_0_mean_ant_rssi'] = data['ap_from_ap_0_mean_ant_rssi'].apply(calculate_sum)
data2['mean_ap_from_ap_0_mean_ant_rssi'] = data2['sum_ap_from_ap_0_mean_ant_rssi']/data2['个数ap_from_ap_0_mean_ant_rssi']
data2['空闲ap_from_ap_0_mean_ant_rssi'] = data2['其他占比ap_from_ap_0_mean_ant_rssi']
data2['繁忙ap_from_ap_0_mean_ant_rssi'] = data2['个数ap_from_ap_0_mean_ant_rssi']-data2['其他占比ap_from_ap_0_mean_ant_rssi']

#ap_from_ap_1
data2['个数ap_from_ap_1_sum_ant_rssi'] = data['ap_from_ap_1_sum_ant_rssi'].apply(calculate_length)
data2['同步传输个数ap_from_ap_1_sum_ant_rssi'] = data['ap_from_ap_1_sum_ant_rssi'].apply(calculate_同步)
data2['同步占比ap_from_ap_1_sum_ant_rssi'] = data2['同步传输个数ap_from_ap_1_sum_ant_rssi']/data2['个数ap_from_ap_1_sum_ant_rssi']
data2['异步传输个数ap_from_ap_1_sum_ant_rssi'] = data['ap_from_ap_1_sum_ant_rssi'].apply(calculate_异步)
data2['异步占比ap_from_ap_1_sum_ant_rssi'] = data2['异步传输个数ap_from_ap_1_sum_ant_rssi']/data2['个数ap_from_ap_1_sum_ant_rssi']
data.loc[data['nav'] == -86, 'NAV传输个数ap_from_ap_1_sum_ant_rssi'] = data['ap_from_ap_1_sum_ant_rssi'].apply(calculate_NAV)
data2['NAV传输个数ap_from_ap_1_sum_ant_rssi'] = data['NAV传输个数ap_from_ap_1_sum_ant_rssi'].fillna(0)
data2['NAV占比ap_from_ap_1_sum_ant_rssi'] = data2['NAV传输个数ap_from_ap_1_sum_ant_rssi']/data2['个数ap_from_ap_1_sum_ant_rssi']
data2['其他传输个数ap_from_ap_1_sum_ant_rssi'] = data2['个数ap_from_ap_1_sum_ant_rssi']-data2['同步传输个数ap_from_ap_1_sum_ant_rssi']-data2['异步传输个数ap_from_ap_1_sum_ant_rssi']-data2['NAV传输个数ap_from_ap_1_sum_ant_rssi']
data2['其他占比ap_from_ap_1_sum_ant_rssi'] = data2['其他传输个数ap_from_ap_1_sum_ant_rssi']/data2['个数ap_from_ap_1_sum_ant_rssi']
data2['sum_ap_from_ap_1_sum_ant_rssi'] = data['ap_from_ap_1_sum_ant_rssi'].apply(calculate_sum)
data2['mean_ap_from_ap_1_sum_ant_rssi'] = data2['sum_ap_from_ap_1_sum_ant_rssi']/data2['个数ap_from_ap_1_sum_ant_rssi']
data2['空闲ap_from_ap_1_sum_ant_rssi'] = data2['其他占比ap_from_ap_1_sum_ant_rssi']
data2['繁忙ap_from_ap_1_sum_ant_rssi'] = data2['个数ap_from_ap_1_sum_ant_rssi']-data2['其他占比ap_from_ap_1_sum_ant_rssi']

data2['个数ap_from_ap_1_max_ant_rssi'] = data['ap_from_ap_1_max_ant_rssi'].apply(calculate_length)
data2['同步传输个数ap_from_ap_1_max_ant_rssi'] = data['ap_from_ap_1_max_ant_rssi'].apply(calculate_同步)
data2['同步占比ap_from_ap_1_max_ant_rssi'] = data2['同步传输个数ap_from_ap_1_max_ant_rssi']/data2['个数ap_from_ap_1_max_ant_rssi']
data2['异步传输个数ap_from_ap_1_max_ant_rssi'] = data['ap_from_ap_1_max_ant_rssi'].apply(calculate_异步)
data2['异步占比ap_from_ap_1_max_ant_rssi'] = data2['异步传输个数ap_from_ap_1_max_ant_rssi']/data2['个数ap_from_ap_1_max_ant_rssi']
data.loc[data['nav'] == -86, 'NAV传输个数ap_from_ap_1_max_ant_rssi'] = data['ap_from_ap_1_max_ant_rssi'].apply(calculate_NAV)
data2['NAV传输个数ap_from_ap_1_max_ant_rssi'] = data['NAV传输个数ap_from_ap_1_max_ant_rssi'].fillna(0)
data2['NAV占比ap_from_ap_1_max_ant_rssi'] = data2['NAV传输个数ap_from_ap_1_max_ant_rssi']/data2['个数ap_from_ap_1_max_ant_rssi']
data2['其他传输个数ap_from_ap_1_max_ant_rssi'] = data2['个数ap_from_ap_1_max_ant_rssi']-data2['同步传输个数ap_from_ap_1_max_ant_rssi']-data2['异步传输个数ap_from_ap_1_max_ant_rssi']-data2['NAV传输个数ap_from_ap_1_max_ant_rssi']
data2['其他占比ap_from_ap_1_max_ant_rssi'] = data2['其他传输个数ap_from_ap_1_max_ant_rssi']/data2['个数ap_from_ap_1_max_ant_rssi']
data2['sum_ap_from_ap_1_max_ant_rssi'] = data['ap_from_ap_1_max_ant_rssi'].apply(calculate_sum)
data2['mean_ap_from_ap_1_max_ant_rssi'] = data2['sum_ap_from_ap_1_max_ant_rssi']/data2['个数ap_from_ap_1_max_ant_rssi']
data2['空闲ap_from_ap_1_max_ant_rssi'] = data2['其他占比ap_from_ap_1_max_ant_rssi']
data2['繁忙ap_from_ap_1_max_ant_rssi'] = data2['个数ap_from_ap_1_max_ant_rssi']-data2['其他占比ap_from_ap_1_max_ant_rssi']

data2['个数ap_from_ap_1_mean_ant_rssi'] = data['ap_from_ap_1_mean_ant_rssi'].apply(calculate_length)
data2['同步传输个数ap_from_ap_1_mean_ant_rssi'] = data['ap_from_ap_1_mean_ant_rssi'].apply(calculate_同步)
data2['同步占比ap_from_ap_1_mean_ant_rssi'] = data2['同步传输个数ap_from_ap_1_mean_ant_rssi']/data2['个数ap_from_ap_1_mean_ant_rssi']
data2['异步传输个数ap_from_ap_1_mean_ant_rssi'] = data['ap_from_ap_1_mean_ant_rssi'].apply(calculate_异步)
data2['异步占比ap_from_ap_1_mean_ant_rssi'] = data2['异步传输个数ap_from_ap_1_mean_ant_rssi']/data2['个数ap_from_ap_1_mean_ant_rssi']
data.loc[data['nav'] == -86, 'NAV传输个数ap_from_ap_1_mean_ant_rssi'] = data['ap_from_ap_1_mean_ant_rssi'].apply(calculate_NAV)
data2['NAV传输个数ap_from_ap_1_mean_ant_rssi'] = data['NAV传输个数ap_from_ap_1_mean_ant_rssi'].fillna(0)
data2['NAV占比ap_from_ap_1_mean_ant_rssi'] = data2['NAV传输个数ap_from_ap_1_mean_ant_rssi']/data2['个数ap_from_ap_1_mean_ant_rssi']
data2['其他传输个数ap_from_ap_1_mean_ant_rssi'] = data2['个数ap_from_ap_1_mean_ant_rssi']-data2['同步传输个数ap_from_ap_1_mean_ant_rssi']-data2['异步传输个数ap_from_ap_1_mean_ant_rssi']-data2['NAV传输个数ap_from_ap_1_mean_ant_rssi']
data2['其他占比ap_from_ap_1_mean_ant_rssi'] = data2['其他传输个数ap_from_ap_1_mean_ant_rssi']/data2['个数ap_from_ap_1_mean_ant_rssi']
data2['sum_ap_from_ap_1_mean_ant_rssi'] = data['ap_from_ap_1_mean_ant_rssi'].apply(calculate_sum)
data2['mean_ap_from_ap_1_mean_ant_rssi'] = data2['sum_ap_from_ap_1_mean_ant_rssi']/data2['个数ap_from_ap_1_mean_ant_rssi']
data2['空闲ap_from_ap_1_mean_ant_rssi'] = data2['其他占比ap_from_ap_1_mean_ant_rssi']
data2['繁忙ap_from_ap_1_mean_ant_rssi'] = data2['个数ap_from_ap_1_mean_ant_rssi']-data2['其他占比ap_from_ap_1_mean_ant_rssi']

#ap_from_ap_2
data2['个数ap_from_ap_2_sum_ant_rssi'] = data['ap_from_ap_2_sum_ant_rssi'].apply(calculate_length)
data2['同步传输个数ap_from_ap_2_sum_ant_rssi'] = data['ap_from_ap_2_sum_ant_rssi'].apply(calculate_同步)
data2['同步占比ap_from_ap_2_sum_ant_rssi'] = data2['同步传输个数ap_from_ap_2_sum_ant_rssi']/data2['个数ap_from_ap_2_sum_ant_rssi']
data2['异步传输个数ap_from_ap_2_sum_ant_rssi'] = data['ap_from_ap_2_sum_ant_rssi'].apply(calculate_异步)
data2['异步占比ap_from_ap_2_sum_ant_rssi'] = data2['异步传输个数ap_from_ap_2_sum_ant_rssi']/data2['个数ap_from_ap_2_sum_ant_rssi']
data.loc[data['nav'] == -86, 'NAV传输个数ap_from_ap_2_sum_ant_rssi'] = data['ap_from_ap_2_sum_ant_rssi'].apply(calculate_NAV)
data2['NAV传输个数ap_from_ap_2_sum_ant_rssi'] = data['NAV传输个数ap_from_ap_2_sum_ant_rssi'].fillna(0)
data2['NAV占比ap_from_ap_2_sum_ant_rssi'] = data2['NAV传输个数ap_from_ap_2_sum_ant_rssi']/data2['个数ap_from_ap_2_sum_ant_rssi']
data2['其他传输个数ap_from_ap_2_sum_ant_rssi'] = data2['个数ap_from_ap_2_sum_ant_rssi']-data2['同步传输个数ap_from_ap_2_sum_ant_rssi']-data2['异步传输个数ap_from_ap_2_sum_ant_rssi']-data2['NAV传输个数ap_from_ap_2_sum_ant_rssi']
data2['其他占比ap_from_ap_2_sum_ant_rssi'] = data2['其他传输个数ap_from_ap_2_sum_ant_rssi']/data2['个数ap_from_ap_2_sum_ant_rssi']
data2['sum_ap_from_ap_2_sum_ant_rssi'] = data['ap_from_ap_2_sum_ant_rssi'].apply(calculate_sum)
data2['mean_ap_from_ap_2_sum_ant_rssi'] = data2['sum_ap_from_ap_2_sum_ant_rssi']/data2['个数ap_from_ap_2_sum_ant_rssi']
data2['空闲ap_from_ap_2_sum_ant_rssi'] = data2['其他占比ap_from_ap_2_sum_ant_rssi']
data2['繁忙ap_from_ap_2_sum_ant_rssi'] = data2['个数ap_from_ap_2_sum_ant_rssi']-data2['其他占比ap_from_ap_2_sum_ant_rssi']

data2['个数ap_from_ap_2_max_ant_rssi'] = data['ap_from_ap_2_max_ant_rssi'].apply(calculate_length)
data2['同步传输个数ap_from_ap_2_max_ant_rssi'] = data['ap_from_ap_2_max_ant_rssi'].apply(calculate_同步)
data2['同步占比ap_from_ap_2_max_ant_rssi'] = data2['同步传输个数ap_from_ap_2_max_ant_rssi']/data2['个数ap_from_ap_2_max_ant_rssi']
data2['异步传输个数ap_from_ap_2_max_ant_rssi'] = data['ap_from_ap_2_max_ant_rssi'].apply(calculate_异步)
data2['异步占比ap_from_ap_2_max_ant_rssi'] = data2['异步传输个数ap_from_ap_2_max_ant_rssi']/data2['个数ap_from_ap_2_max_ant_rssi']
data.loc[data['nav'] == -86, 'NAV传输个数ap_from_ap_2_max_ant_rssi'] = data['ap_from_ap_2_max_ant_rssi'].apply(calculate_NAV)
data2['NAV传输个数ap_from_ap_2_max_ant_rssi'] = data['NAV传输个数ap_from_ap_2_max_ant_rssi'].fillna(0)
data2['NAV占比ap_from_ap_2_max_ant_rssi'] = data2['NAV传输个数ap_from_ap_2_max_ant_rssi']/data2['个数ap_from_ap_2_max_ant_rssi']
data2['其他传输个数ap_from_ap_2_max_ant_rssi'] = data2['个数ap_from_ap_2_max_ant_rssi']-data2['同步传输个数ap_from_ap_2_max_ant_rssi']-data2['异步传输个数ap_from_ap_2_max_ant_rssi']-data2['NAV传输个数ap_from_ap_2_max_ant_rssi']
data2['其他占比ap_from_ap_2_max_ant_rssi'] = data2['其他传输个数ap_from_ap_2_max_ant_rssi']/data2['个数ap_from_ap_2_max_ant_rssi']
data2['sum_ap_from_ap_2_max_ant_rssi'] = data['ap_from_ap_2_max_ant_rssi'].apply(calculate_sum)
data2['mean_ap_from_ap_2_max_ant_rssi'] = data2['sum_ap_from_ap_2_max_ant_rssi']/data2['个数ap_from_ap_2_max_ant_rssi']
data2['空闲ap_from_ap_2_max_ant_rssi'] = data2['其他占比ap_from_ap_2_max_ant_rssi']
data2['繁忙ap_from_ap_2_max_ant_rssi'] = data2['个数ap_from_ap_2_max_ant_rssi']-data2['其他占比ap_from_ap_2_max_ant_rssi']

data2['个数ap_from_ap_2_mean_ant_rssi'] = data['ap_from_ap_2_mean_ant_rssi'].apply(calculate_length)
data2['同步传输个数ap_from_ap_2_mean_ant_rssi'] = data['ap_from_ap_2_mean_ant_rssi'].apply(calculate_同步)
data2['同步占比ap_from_ap_2_mean_ant_rssi'] = data2['同步传输个数ap_from_ap_2_mean_ant_rssi']/data2['个数ap_from_ap_2_mean_ant_rssi']
data2['异步传输个数ap_from_ap_2_mean_ant_rssi'] = data['ap_from_ap_2_mean_ant_rssi'].apply(calculate_异步)
data2['异步占比ap_from_ap_2_mean_ant_rssi'] = data2['异步传输个数ap_from_ap_2_mean_ant_rssi']/data2['个数ap_from_ap_2_mean_ant_rssi']
data.loc[data['nav'] == -86, 'NAV传输个数ap_from_ap_2_mean_ant_rssi'] = data['ap_from_ap_2_mean_ant_rssi'].apply(calculate_NAV)
data2['NAV传输个数ap_from_ap_2_mean_ant_rssi'] = data['NAV传输个数ap_from_ap_2_mean_ant_rssi'].fillna(0)
data2['NAV占比ap_from_ap_2_mean_ant_rssi'] = data2['NAV传输个数ap_from_ap_2_mean_ant_rssi']/data2['个数ap_from_ap_2_mean_ant_rssi']
data2['其他传输个数ap_from_ap_2_mean_ant_rssi'] = data2['个数ap_from_ap_2_mean_ant_rssi']-data2['同步传输个数ap_from_ap_2_mean_ant_rssi']-data2['异步传输个数ap_from_ap_2_mean_ant_rssi']-data2['NAV传输个数ap_from_ap_2_mean_ant_rssi']
data2['其他占比ap_from_ap_2_mean_ant_rssi'] = data2['其他传输个数ap_from_ap_2_mean_ant_rssi']/data2['个数ap_from_ap_2_mean_ant_rssi']
data2['sum_ap_from_ap_2_mean_ant_rssi'] = data['ap_from_ap_2_mean_ant_rssi'].apply(calculate_sum)
data2['mean_ap_from_ap_2_mean_ant_rssi'] = data2['sum_ap_from_ap_2_mean_ant_rssi']/data2['个数ap_from_ap_2_mean_ant_rssi']
data2['空闲ap_from_ap_2_mean_ant_rssi'] = data2['其他占比ap_from_ap_2_mean_ant_rssi']
data2['繁忙ap_from_ap_2_mean_ant_rssi'] = data2['个数ap_from_ap_2_mean_ant_rssi']-data2['其他占比ap_from_ap_2_mean_ant_rssi']

#sta
columns2 = ["sta_to_ap_0_sum_ant_rssi","sta_to_ap_0_max_ant_rssi","sta_to_ap_0_mean_ant_rssi",
  "sta_to_ap_1_sum_ant_rssi","sta_to_ap_1_max_ant_rssi","sta_to_ap_1_mean_ant_rssi",
  "sta_to_ap_2_sum_ant_rssi", "sta_to_ap_2_max_ant_rssi","sta_to_ap_2_mean_ant_rssi",
  "sta_from_ap_0_sum_ant_rssi","sta_from_ap_0_max_ant_rssi","sta_from_ap_0_mean_ant_rssi",
  "sta_from_ap_1_sum_ant_rssi","sta_from_ap_1_max_ant_rssi","sta_from_ap_1_mean_ant_rssi",
  "sta_from_ap_2_sum_ant_rssi", "sta_from_ap_2_max_ant_rssi","sta_from_ap_2_mean_ant_rssi"]
for column in columns2:
    data[column] = data[column].apply(try_convert_to_list)
def calculate_sum_and_mean(data2,data, column_name):
    data2[f'个数{column_name}'] = data[column_name].apply(calculate_length)
    data2[f'总和{column_name}'] = data[column_name].apply(calculate_sum)
    data2[f'平均{column_name}'] = data2[f'总和{column_name}']/data2[f'个数{column_name}']
for column in columns2:
    calculate_sum_and_mean(data2,data, column)
data2['sta_from_sta_0_rssi'] = data['sta_from_sta_0_rssi']
data2['sta_from_sta_1_rssi'] = data['sta_from_sta_1_rssi']
data2['sta_from_sta_2_rssi'] = data['sta_from_sta_2_rssi']

#SINR
import numpy as np
data2['SINR_sum'] = abs(data2['平均sta_from_ap_0_sum_ant_rssi'] - np.maximum(data2['平均sta_from_ap_1_sum_ant_rssi'], data2['平均sta_from_ap_2_sum_ant_rssi']))
data2['SINR_max'] = abs(data2['平均sta_from_ap_0_max_ant_rssi']-data2['平均sta_from_ap_1_max_ant_rssi'])
data2['SINR_mean'] = abs(data2['平均sta_from_ap_0_mean_ant_rssi']-data2['平均sta_from_ap_1_mean_ant_rssi'])

#PHY Rate
data2['nss'] = data['nss']
data2['mcs'] = data['mcs']
def get_phy_rate(mcs, nss):
    mcs_NSS_rates = {
        (0, 1): 8.6, (1, 1): 17.2, (2, 1): 25.8, (3, 1): 34.4, (4, 1): 51.6,
        (5, 1): 68.8, (6, 1): 77.4, (7, 1): 86.0, (8, 1): 103.2, (9, 1): 114.7,
        (10, 1): 129.0, (11, 1): 143.4,
        (0, 2): 17.2, (1, 2): 34.4, (2, 2): 51.6, (3, 2): 68.8, (4, 2): 103.2,
        (5, 2): 137.6, (6, 2): 154.9, (7, 2): 172.1, (8, 2): 206.5, (9, 2): 229.4,
        (10, 2): 258.1, (11, 2): 286.8
    }
    return mcs_NSS_rates.get((mcs, nss), None)
data2['PHY Rate'] = data.apply(lambda row: get_phy_rate(row['mcs'], row['nss']), axis=1)

#数据包
data2['Packet Size'] = 12000
data2['Transmission Time'] = data2['PHY Rate']/data2['Packet Size']

data2['per'] = data['per']
data2['num_ampdu'] = data['num_ampdu']
data2['ppdu_dur'] = data['ppdu_dur']
data2['other_air_time'] = data['other_air_time']
data2['seq_time'] = data['seq_time']
data2['throughput'] = data['throughput']

data2.to_excel('102特征工程3AP_pro.xlsx',index = False)
datax = data2
# Out:
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_9376\2009338891.py:138: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data2['同步传输个数ap_from_ap_2_max_ant_rssi'] = data['ap_from_ap_2_max_ant_rssi'].apply(calculate_同步)
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_9376\2009338891.py:139: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data2['同步占比ap_from_ap_2_max_ant_rssi'] = data2['同步传输个数ap_from_ap_2_max_ant_rssi']/data2['个数ap_from_ap_2_max_ant_rssi']
# ...

# %%
data3 = pd.DataFrame()
data3['loc_id'] = data2['loc_id']
data3['protocol'] = data2['protocol']
data3['bss_id'] = data2['bss_id']
data3['sta_mac'] = data2['sta_mac']
data3['pd'] = data2['pd']
data3['ed'] = data2['ed']
data3['nav'] = data2['nav']
data3['eirp'] = data2['eirp']
#AP
data3['number_AfromA0_sum'] = data2['个数ap_from_ap_0_sum_ant_rssi']
data3['mean_AfromA0_sum'] = data2['mean_ap_from_ap_0_sum_ant_rssi']
data3['idle_Prop_AfromA0'] = data2['空闲ap_from_ap_0_sum_ant_rssi']/data2['个数ap_from_ap_0_sum_ant_rssi']
data3['busy_Prop_AfromA0'] = 1-data3['idle_Prop_AfromA0']
data3['number_AfromA0_max'] = data2['个数ap_from_ap_0_max_ant_rssi']
data3['mean_AfromA0_max'] = data2['mean_ap_from_ap_0_max_ant_rssi']
data3['syn_Prop_AfromA0'] = data2['同步占比ap_from_ap_0_max_ant_rssi']
data3['asyns_Prop_AfromA0'] = data2['异步占比ap_from_ap_0_max_ant_rssi']
data3['number_AfromA0_mean'] = data2['个数ap_from_ap_0_mean_ant_rssi']
data3['mean_AfromA0_mean'] = data2['mean_ap_from_ap_0_mean_ant_rssi']
data3['NAV_Prop_AfromA0'] = data2['NAV占比ap_from_ap_0_mean_ant_rssi']

data3['number_AfromA1_sum'] = data2['个数ap_from_ap_1_sum_ant_rssi']
data3['mean_AfromA1_sum'] = data2['mean_ap_from_ap_1_sum_ant_rssi']
data3['idle_Prop_AfromA1'] = data2['空闲ap_from_ap_1_sum_ant_rssi']/data2['个数ap_from_ap_1_sum_ant_rssi']
data3['busy_Prop_AfromA1'] = 1-data3['idle_Prop_AfromA1']
data3['number_AfromA1_max'] = data2['个数ap_from_ap_1_max_ant_rssi']
data3['mean_AfromA1_max'] = data2['mean_ap_from_ap_1_max_ant_rssi']
data3['syn_Prop_AfromA1'] = data2['同步占比ap_from_ap_1_max_ant_rssi']
data3['asyns_Prop_AfromA1'] = data2['异步占比ap_from_ap_1_max_ant_rssi']
data3['number_AfromA1_mean'] = data2['个数ap_from_ap_1_mean_ant_rssi']
data3['mean_AfromA1_mean'] = data2['mean_ap_from_ap_1_mean_ant_rssi']
data3['NAV_Prop_AfromA1'] = data2['NAV占比ap_from_ap_1_mean_ant_rssi']

data3['number_AfromA2_sum'] = data2['个数ap_from_ap_2_sum_ant_rssi']
data3['mean_AfromA2_sum'] = data2['mean_ap_from_ap_2_sum_ant_rssi']
data3['idle_Prop_AfromA2'] = data2['空闲ap_from_ap_2_sum_ant_rssi']/data2['个数ap_from_ap_2_sum_ant_rssi']
data3['busy_Prop_AfromA2'] = 1-data3['idle_Prop_AfromA2']
data3['number_AfromA2_max'] = data2['个数ap_from_ap_2_max_ant_rssi']
data3['mean_AfromA2_max'] = data2['mean_ap_from_ap_2_max_ant_rssi']
data3['syn_Prop_AfromA2'] = data2['同步占比ap_from_ap_2_max_ant_rssi']
data3['asyns_Prop_AfromA2'] = data2['异步占比ap_from_ap_2_max_ant_rssi']
data3['number_AfromA2_mean'] = data2['个数ap_from_ap_2_mean_ant_rssi']
data3['mean_AfromA2_mean'] = data2['mean_ap_from_ap_2_mean_ant_rssi']
data3['NAV_Prop_AfromA2'] = data2['NAV占比ap_from_ap_2_mean_ant_rssi']

#sta
data3['mean_StoA0_sum'] = data2['平均sta_to_ap_0_sum_ant_rssi']
data3['mean_StoA0_max'] = data2['平均sta_to_ap_0_max_ant_rssi']
data3['mean_StoA0_mean'] = data2['平均sta_to_ap_0_mean_ant_rssi']
data3['mean_StoA1_sum'] = data2['平均sta_to_ap_1_sum_ant_rssi']
data3['mean_StoA1_max'] = data2['平均sta_to_ap_1_max_ant_rssi']
data3['mean_StoA1_mean'] = data2['平均sta_to_ap_1_mean_ant_rssi']
data3['mean_StoA2_sum'] = data2['平均sta_to_ap_2_sum_ant_rssi']
data3['mean_StoA2_max'] = data2['平均sta_to_ap_2_max_ant_rssi']
data3['mean_StoA2_mean'] = data2['平均sta_to_ap_2_mean_ant_rssi']

data3['mean_SfromA0_sum'] = data2['平均sta_from_ap_0_sum_ant_rssi']
data3['mean_SfromA0_max'] = data2['平均sta_from_ap_0_max_ant_rssi']
data3['mean_SfromA0_mean'] = data2['平均sta_from_ap_0_mean_ant_rssi']
data3['mean_SfromA1_sum'] = data2['平均sta_from_ap_1_sum_ant_rssi']
data3['mean_SfromA1_max'] = data2['平均sta_from_ap_1_max_ant_rssi']
data3['mean_SfromA1_mean'] = data2['平均sta_from_ap_1_mean_ant_rssi']
data3['mean_SfromA2_sum'] = data2['平均sta_from_ap_2_sum_ant_rssi']
data3['mean_SfromA2_max'] = data2['平均sta_from_ap_2_max_ant_rssi']
data3['mean_SfromA2_mean'] = data2['平均sta_from_ap_2_mean_ant_rssi']

data3['SfromS0'] = data2['sta_from_sta_0_rssi']
data3['SfromS1'] = data2['sta_from_sta_1_rssi']
data3['SfromS2'] = data2['sta_from_sta_2_rssi']

data3['SINR_sum'] = data2['SINR_sum']
data3['SINR_max'] = data2['SINR_sum']
data3['SINR_mean'] = data2['SINR_sum']

#PHY Rate
data3['nss'] = data2['nss']
data3['mcs'] = data2['mcs']
data3['PHY_Rate'] = data2['PHY Rate']

#数据包
data3['Transmission_Time'] = data3['PHY_Rate']/12000

data3['per'] = data2['per']
data3['num_ampdu'] = data2['num_ampdu']
data3['ppdu_dur'] = data2['ppdu_dur']
data3['other_air_time'] = data2['other_air_time']
data3['seq_time'] = data2['seq_time']
data3['throughput'] = data2['throughput']

print(data3)
data3 = data3.fillna(0)
data3.to_excel('102特征工程3AP.xlsx',index = False)
# Out:
#     loc_id protocol  bss_id sta_mac  pd  ed  nav  eirp  number_AfromA0_sum  \
# 0    loc30      tcp       2    1287 -82 -62  -82     9                  61
# 1    loc30      tcp       1    6d53 -82 -62  -82     9                  61
# 2    loc30      tcp       0    8889 -82 -62  -82     9                   0
# 3    loc30      udp       2    1287 -82 -62  -82     9                  61
# 4    loc30      udp       1    6d53 -82 -62  -82     9                  61
# 5    loc30      udp       0    8889 -82 -62  -82     9                   0
# 6    loc30      tcp       2    1287 -82 -62  -82    10                  68
# 7    loc30      tcp       1    6d53 -82 -62  -82    10                  60
# 8    loc30      tcp       0    8889 -82 -62  -82    10                   0
# 9    loc30      udp       2    1287 -82 -62  -82    10                  68
# 10   loc30      udp       1    6d53 -82 -62  -82    10                  60
# ...
